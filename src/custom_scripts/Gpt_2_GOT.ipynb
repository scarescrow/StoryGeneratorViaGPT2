# %%
# Download GPT-2 (small 117M model)

# !git clone https://github.com/nshepperd/gpt-2
# %cd gpt-2

# !python download_model.py 117M

# !pip3 install -r requirements.txt
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 212, done.
# remote: Total 212 (delta 0), reused 0 (delta 0), pack-reused 212
# Receiving objects: 100% (212/212), 4.37 MiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (112/112), done.
# /content/gpt-2
# Fetching checkpoint: 1.00kit [00:00, 662kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 55.1Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 749kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:06, 72.5Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 3.66Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 33.5Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 53.0Mit/s]
# ...
#     100% |████████████████████████████████| 604kB 25.6MB/s
# ...
#     100% |████████████████████████████████| 51kB 25.1MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/2a/1a/4d/6b30377c3051e76559d1185c1dbbfff15aed31f87acdd14c22
# ...
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !mkdir src/models
# !mv models/* src/models/
# !rmdir models

# %%
# !mv train.py src/train.py

# %%
path = "/content/drive/My Drive/StoryCompletion/got"

# %%
# %cd /content/gpt-2/src
# Out:
# /content/gpt-2/src

# %%
# !rm -r checkpoint/*

# %%
# !python train.py --dataset "/content/drive/My Drive/StoryCompletion/got"
# Out:
# 2019-04-07 01:16:08.822399: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-07 01:16:08.822651: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1c603c0 executing computations on platform Host. Devices:
# 2019-04-07 01:16:08.822689: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-04-07 01:16:08.912904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-04-07 01:16:08.913495: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1c60100 executing computations on platform CUDA. Devices:
# 2019-04-07 01:16:08.913533: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# ...

# %%
# !mkdir models/got
# !cp -r checkpoint/run1/* models/got/
# !cp models/117M/encoder.json models/got/encoder.json
# !cp models/117M/hparams.json models/got/hparams.json
# !cp models/117M/vocab.bpe models/got/vocab.bpe

# %%
# Out:
# mkdir: cannot create directory ‘models/got’: No such file or directory

# %%
# !mkdir "/content/drive/My Drive/StoryCompletion/GOTWeights"
# !cp -r models/hp/* "/content/drive/My Drive/StoryCompletion/GOTWeights/"
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/StoryCompletion/HPWeights’: File exists

# %%
# %cd /content/gpt-2/src/
# Out:
# /content/gpt-2/src

# %%
from interactive_conditional_samples import *

# %%
interact_model(model_name="got")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# ...
