# %%
import pandas as pd

# %%
df = pd.read_excel("4000-Stories-with-sentiment-analysis.xlsx")

# %%
df.head()
# Out:
#                                                  url  length  \
# 0  https://americanliterature.com/author/eleanor-...   15044
# 1  https://americanliterature.com/author/eleanor-...   10874
# 2  https://americanliterature.com/author/achmed-a...    6922
# 3  https://americanliterature.com/author/achmed-a...    4371
# 4  https://americanliterature.com/author/achmed-a...    3413
#
#                                title  text_no                    author  \
# 0  Peace on Earth, Good-Will to Dogs        0  Eleanor Hallowell Abbott
# 1              The Indiscreet Letter        1  Eleanor Hallowell Abbott
# 2                    An Act of Piety        2           Achmed Abdullah
# 3                   An Indian Jataka        3           Achmed Abdullah
# 4                               Fear        4           Achmed Abdullah
#
#                                                story   valence   arousal  \
# 0  PART I\n\nIf you don't like Christmas stories,...  0.592896  0.397839
# ...

# %%
stories = df["story"].str.cat(sep="\n\n\n")

# %%
with open("stories.txt", "w", encoding="utf8") as fp:
    fp.write(stories)
